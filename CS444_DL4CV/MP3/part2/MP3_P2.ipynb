# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = None #'checkpoints/best_detector.pth' 
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)
# Out:
# Load pre-trained model
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and may be removed in the future, "
# /opt/conda/lib/python3.7/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
learning_rate = 0.001
num_epochs = 60
batch_size = 8

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = 'data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = 'data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = 1e-3
for epoch in range(num_epochs):
    net.train()
    
    # Update learning rate late in training
    if epoch == 30:
        learning_rate = 5e-4
    elif epoch == 50:
        learning_rate = 1e-4

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate
    
    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))
    
    total_loss = collections.defaultdict(int)
    
    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()
        
        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()
        
        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)
    
    # evaluate the network on the test data
    if (epoch + 1) % 5 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data
            
            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)
    
    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')
    
    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 60
# Learning Rate for this epoch: 0.001
# Epoch [1/60], Iter [50/627], Loss: total=27.246, reg=0.906, containing_obj=0.323, no_obj=25.175, cls=9.803
# Epoch [1/60], Iter [100/627], Loss: total=17.873, reg=0.756, containing_obj=0.376, no_obj=13.044, cls=7.194
# Epoch [1/60], Iter [150/627], Loss: total=14.403, reg=0.681, containing_obj=0.425, no_obj=8.907, cls=6.122
# Epoch [1/60], Iter [200/627], Loss: total=12.630, reg=0.645, containing_obj=0.471, no_obj=6.805, cls=5.531
# Epoch [1/60], Iter [250/627], Loss: total=11.390, reg=0.612, containing_obj=0.503, no_obj=5.527, cls=5.065
# Epoch [1/60], Iter [300/627], Loss: total=10.531, reg=0.591, containing_obj=0.533, no_obj=4.665, cls=4.709
# Epoch [1/60], Iter [350/627], Loss: total=9.805, reg=0.569, containing_obj=0.549, no_obj=4.044, cls=4.390
# Epoch [1/60], Iter [400/627], Loss: total=9.308, reg=0.556, containing_obj=0.570, no_obj=3.574, cls=4.174
# Epoch [1/60], Iter [450/627], Loss: total=8.868, reg=0.542, containing_obj=0.585, no_obj=3.205, cls=3.971
# Epoch [1/60], Iter [500/627], Loss: total=8.503, reg=0.530, containing_obj=0.595, no_obj=2.908, cls=3.801
# Epoch [1/60], Iter [550/627], Loss: total=8.208, reg=0.522, containing_obj=0.607, no_obj=2.664, cls=3.661
# Epoch [1/60], Iter [600/627], Loss: total=7.942, reg=0.513, containing_obj=0.615, no_obj=2.459, cls=3.531
# Updating best test loss: 5.12076
#
#
# Starting epoch 2 / 60
# Learning Rate for this epoch: 0.001
# Epoch [2/60], Iter [50/627], Loss: total=4.939, reg=0.409, containing_obj=0.751, no_obj=0.185, cls=2.051
# Epoch [2/60], Iter [100/627], Loss: total=4.952, reg=0.412, containing_obj=0.746, no_obj=0.180, cls=2.055
# Epoch [2/60], Iter [150/627], Loss: total=4.943, reg=0.409, containing_obj=0.747, no_obj=0.176, cls=2.065
# Epoch [2/60], Iter [200/627], Loss: total=4.930, reg=0.413, containing_obj=0.755, no_obj=0.171, cls=2.025
# Epoch [2/60], Iter [250/627], Loss: total=4.868, reg=0.409, containing_obj=0.762, no_obj=0.168, cls=1.975
# Epoch [2/60], Iter [300/627], Loss: total=4.874, reg=0.411, containing_obj=0.765, no_obj=0.165, cls=1.969
# Epoch [2/60], Iter [350/627], Loss: total=4.911, reg=0.414, containing_obj=0.770, no_obj=0.161, cls=1.989
# Epoch [2/60], Iter [400/627], Loss: total=4.873, reg=0.413, containing_obj=0.775, no_obj=0.159, cls=1.955
# Epoch [2/60], Iter [450/627], Loss: total=4.832, reg=0.408, containing_obj=0.774, no_obj=0.156, cls=1.940
# Epoch [2/60], Iter [500/627], Loss: total=4.848, reg=0.410, containing_obj=0.779, no_obj=0.154, cls=1.942
# Epoch [2/60], Iter [550/627], Loss: total=4.833, reg=0.410, containing_obj=0.783, no_obj=0.151, cls=1.926
# Epoch [2/60], Iter [600/627], Loss: total=4.806, reg=0.408, containing_obj=0.784, no_obj=0.149, cls=1.907
# Updating best test loss: 4.62672
#
#
# Starting epoch 3 / 60
# Learning Rate for this epoch: 0.001
# Epoch [3/60], Iter [50/627], Loss: total=4.684, reg=0.409, containing_obj=0.847, no_obj=0.124, cls=1.731
# Epoch [3/60], Iter [100/627], Loss: total=4.623, reg=0.402, containing_obj=0.841, no_obj=0.124, cls=1.712
# Epoch [3/60], Iter [150/627], Loss: total=4.508, reg=0.389, containing_obj=0.832, no_obj=0.123, cls=1.671
# Epoch [3/60], Iter [200/627], Loss: total=4.477, reg=0.386, containing_obj=0.828, no_obj=0.123, cls=1.655
# Epoch [3/60], Iter [250/627], Loss: total=4.490, reg=0.387, containing_obj=0.831, no_obj=0.123, cls=1.661
# Epoch [3/60], Iter [300/627], Loss: total=4.473, reg=0.385, containing_obj=0.833, no_obj=0.123, cls=1.652
# Epoch [3/60], Iter [350/627], Loss: total=4.458, reg=0.387, containing_obj=0.826, no_obj=0.123, cls=1.636
# Epoch [3/60], Iter [400/627], Loss: total=4.407, reg=0.382, containing_obj=0.823, no_obj=0.123, cls=1.614
# Epoch [3/60], Iter [450/627], Loss: total=4.406, reg=0.382, containing_obj=0.819, no_obj=0.124, cls=1.617
# Epoch [3/60], Iter [500/627], Loss: total=4.433, reg=0.384, containing_obj=0.826, no_obj=0.124, cls=1.624
# Epoch [3/60], Iter [550/627], Loss: total=4.415, reg=0.382, containing_obj=0.824, no_obj=0.125, cls=1.618
# Epoch [3/60], Iter [600/627], Loss: total=4.406, reg=0.380, containing_obj=0.825, no_obj=0.125, cls=1.616
# Updating best test loss: 4.37266
#
#
# Starting epoch 4 / 60
# Learning Rate for this epoch: 0.001
# Epoch [4/60], Iter [50/627], Loss: total=4.146, reg=0.359, containing_obj=0.826, no_obj=0.137, cls=1.459
# Epoch [4/60], Iter [100/627], Loss: total=4.208, reg=0.364, containing_obj=0.848, no_obj=0.137, cls=1.472
# Epoch [4/60], Iter [150/627], Loss: total=4.233, reg=0.365, containing_obj=0.843, no_obj=0.140, cls=1.495
# Epoch [4/60], Iter [200/627], Loss: total=4.182, reg=0.362, containing_obj=0.828, no_obj=0.141, cls=1.473
# Epoch [4/60], Iter [250/627], Loss: total=4.162, reg=0.364, containing_obj=0.821, no_obj=0.143, cls=1.449
# Epoch [4/60], Iter [300/627], Loss: total=4.192, reg=0.367, containing_obj=0.828, no_obj=0.144, cls=1.458
# Epoch [4/60], Iter [350/627], Loss: total=4.214, reg=0.369, containing_obj=0.831, no_obj=0.144, cls=1.466
# Epoch [4/60], Iter [400/627], Loss: total=4.193, reg=0.366, containing_obj=0.834, no_obj=0.146, cls=1.457
# Epoch [4/60], Iter [450/627], Loss: total=4.168, reg=0.364, containing_obj=0.828, no_obj=0.148, cls=1.446
# Epoch [4/60], Iter [500/627], Loss: total=4.167, reg=0.364, containing_obj=0.828, no_obj=0.149, cls=1.444
# Epoch [4/60], Iter [550/627], Loss: total=4.165, reg=0.364, containing_obj=0.829, no_obj=0.150, cls=1.440
# Epoch [4/60], Iter [600/627], Loss: total=4.158, reg=0.364, containing_obj=0.827, no_obj=0.150, cls=1.438
# Updating best test loss: 4.12513
#
#
# Starting epoch 5 / 60
# Learning Rate for this epoch: 0.001
# Epoch [5/60], Iter [50/627], Loss: total=3.906, reg=0.339, containing_obj=0.780, no_obj=0.168, cls=1.345
# Epoch [5/60], Iter [100/627], Loss: total=4.126, reg=0.358, containing_obj=0.823, no_obj=0.164, cls=1.430
# Epoch [5/60], Iter [150/627], Loss: total=4.048, reg=0.352, containing_obj=0.809, no_obj=0.167, cls=1.395
# Epoch [5/60], Iter [200/627], Loss: total=4.070, reg=0.357, containing_obj=0.817, no_obj=0.169, cls=1.382
# Epoch [5/60], Iter [250/627], Loss: total=4.038, reg=0.355, containing_obj=0.810, no_obj=0.171, cls=1.367
# Epoch [5/60], Iter [300/627], Loss: total=3.987, reg=0.353, containing_obj=0.799, no_obj=0.171, cls=1.340
# Epoch [5/60], Iter [350/627], Loss: total=3.990, reg=0.354, containing_obj=0.801, no_obj=0.172, cls=1.331
# Epoch [5/60], Iter [400/627], Loss: total=3.981, reg=0.354, containing_obj=0.807, no_obj=0.172, cls=1.316
# Epoch [5/60], Iter [450/627], Loss: total=3.998, reg=0.355, containing_obj=0.805, no_obj=0.172, cls=1.330
# Epoch [5/60], Iter [500/627], Loss: total=3.990, reg=0.356, containing_obj=0.805, no_obj=0.173, cls=1.321
# Epoch [5/60], Iter [550/627], Loss: total=3.960, reg=0.353, containing_obj=0.800, no_obj=0.174, cls=1.309
# Epoch [5/60], Iter [600/627], Loss: total=3.954, reg=0.354, containing_obj=0.800, no_obj=0.175, cls=1.299
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:16<00:00, 36.25it/s]
# ---class aeroplane ap 0.03373757991433487---
# ---class bicycle ap 0.08330834298115612---
# ---class bird ap 0.0009682885499878965---
# ---class boat ap 0.0---
# ---class bottle ap 0.0--- (no predictions for this class)
# ---class bus ap 0.009389671361502348---
# ---class car ap 0.28033117479194225---
# ---class cat ap 0.11501041560702721---
# ---class chair ap 0.021640068299603514---
# ---class cow ap 0.0--- (no predictions for this class)
# ---class diningtable ap 0.0--- (no predictions for this class)
# ---class dog ap 0.014655760054533062---
# ---class horse ap 0.1283056680758393---
# ---class motorbike ap 0.1317223144365661---
# ---class person ap 0.1462446600082773---
# ---class pottedplant ap 0.0---
# ---class sheep ap 0.0--- (no predictions for this class)
# ---class sofa ap 0.0--- (no predictions for this class)
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.022234461966604824---
# ---map 0.04937742030236873---
# 4 [0.03373757991433487, 0.08330834298115612, 0.0009682885499878965, 0.0, 0.0, 0.009389671361502348, 0.28033117479194225, 0.11501041560702721, 0.021640068299603514, 0.0, 0.0, 0.014655760054533062, 0.1283056680758393, 0.1317223144365661, 0.1462446600082773, 0.0, 0.0, 0.0, 0.0, 0.022234461966604824]
# Updating best test loss: 3.92438
#
#
# Starting epoch 6 / 60
# Learning Rate for this epoch: 0.001
# Epoch [6/60], Iter [50/627], Loss: total=3.477, reg=0.300, containing_obj=0.732, no_obj=0.201, cls=1.143
# Epoch [6/60], Iter [100/627], Loss: total=3.578, reg=0.313, containing_obj=0.761, no_obj=0.194, cls=1.155
# Epoch [6/60], Iter [150/627], Loss: total=3.695, reg=0.330, containing_obj=0.786, no_obj=0.195, cls=1.163
# Epoch [6/60], Iter [200/627], Loss: total=3.681, reg=0.327, containing_obj=0.787, no_obj=0.196, cls=1.163
# Epoch [6/60], Iter [250/627], Loss: total=3.663, reg=0.324, containing_obj=0.790, no_obj=0.198, cls=1.154
# Epoch [6/60], Iter [300/627], Loss: total=3.705, reg=0.329, containing_obj=0.791, no_obj=0.197, cls=1.170
# Epoch [6/60], Iter [350/627], Loss: total=3.717, reg=0.332, containing_obj=0.793, no_obj=0.198, cls=1.168
# Epoch [6/60], Iter [400/627], Loss: total=3.700, reg=0.330, containing_obj=0.792, no_obj=0.198, cls=1.158
# Epoch [6/60], Iter [450/627], Loss: total=3.661, reg=0.328, containing_obj=0.784, no_obj=0.199, cls=1.135
# Epoch [6/60], Iter [500/627], Loss: total=3.689, reg=0.332, containing_obj=0.790, no_obj=0.200, cls=1.141
# Epoch [6/60], Iter [550/627], Loss: total=3.687, reg=0.332, containing_obj=0.790, no_obj=0.202, cls=1.135
# Epoch [6/60], Iter [600/627], Loss: total=3.692, reg=0.334, containing_obj=0.791, no_obj=0.204, cls=1.128
# Updating best test loss: 3.67637
#
#
# Starting epoch 7 / 60
# Learning Rate for this epoch: 0.001
# Epoch [7/60], Iter [50/627], Loss: total=3.532, reg=0.325, containing_obj=0.783, no_obj=0.222, cls=1.012
# Epoch [7/60], Iter [100/627], Loss: total=3.567, reg=0.323, containing_obj=0.810, no_obj=0.216, cls=1.035
# Epoch [7/60], Iter [150/627], Loss: total=3.515, reg=0.317, containing_obj=0.793, no_obj=0.220, cls=1.029
# Epoch [7/60], Iter [200/627], Loss: total=3.525, reg=0.322, containing_obj=0.790, no_obj=0.219, cls=1.018
# Epoch [7/60], Iter [250/627], Loss: total=3.522, reg=0.321, containing_obj=0.795, no_obj=0.222, cls=1.011
# Epoch [7/60], Iter [300/627], Loss: total=3.558, reg=0.324, containing_obj=0.798, no_obj=0.221, cls=1.028
# Epoch [7/60], Iter [350/627], Loss: total=3.538, reg=0.323, containing_obj=0.790, no_obj=0.221, cls=1.024
# Epoch [7/60], Iter [400/627], Loss: total=3.552, reg=0.324, containing_obj=0.791, no_obj=0.223, cls=1.029
# Epoch [7/60], Iter [450/627], Loss: total=3.567, reg=0.326, containing_obj=0.792, no_obj=0.223, cls=1.036
# Epoch [7/60], Iter [500/627], Loss: total=3.549, reg=0.324, containing_obj=0.788, no_obj=0.222, cls=1.030
# Epoch [7/60], Iter [550/627], Loss: total=3.549, reg=0.324, containing_obj=0.790, no_obj=0.222, cls=1.029
# Epoch [7/60], Iter [600/627], Loss: total=3.535, reg=0.323, containing_obj=0.786, no_obj=0.224, cls=1.020
# Updating best test loss: 3.66709
#
#
# Starting epoch 8 / 60
# Learning Rate for this epoch: 0.001
# Epoch [8/60], Iter [50/627], Loss: total=3.658, reg=0.339, containing_obj=0.858, no_obj=0.237, cls=0.984
# Epoch [8/60], Iter [100/627], Loss: total=3.453, reg=0.325, containing_obj=0.808, no_obj=0.240, cls=0.899
# Epoch [8/60], Iter [150/627], Loss: total=3.390, reg=0.317, containing_obj=0.785, no_obj=0.247, cls=0.896
# Epoch [8/60], Iter [200/627], Loss: total=3.390, reg=0.314, containing_obj=0.787, no_obj=0.245, cls=0.910
# Epoch [8/60], Iter [250/627], Loss: total=3.372, reg=0.312, containing_obj=0.777, no_obj=0.245, cls=0.912
# Epoch [8/60], Iter [300/627], Loss: total=3.383, reg=0.313, containing_obj=0.779, no_obj=0.247, cls=0.918
# Epoch [8/60], Iter [350/627], Loss: total=3.371, reg=0.311, containing_obj=0.773, no_obj=0.250, cls=0.918
# Epoch [8/60], Iter [400/627], Loss: total=3.382, reg=0.312, containing_obj=0.775, no_obj=0.249, cls=0.921
# Epoch [8/60], Iter [450/627], Loss: total=3.371, reg=0.311, containing_obj=0.776, no_obj=0.249, cls=0.917
# Epoch [8/60], Iter [500/627], Loss: total=3.408, reg=0.315, containing_obj=0.782, no_obj=0.248, cls=0.926
# Epoch [8/60], Iter [550/627], Loss: total=3.398, reg=0.315, containing_obj=0.779, no_obj=0.248, cls=0.919
# Epoch [8/60], Iter [600/627], Loss: total=3.389, reg=0.315, containing_obj=0.775, no_obj=0.247, cls=0.913
# Updating best test loss: 3.44928
#
#
# Starting epoch 9 / 60
# Learning Rate for this epoch: 0.001
# Epoch [9/60], Iter [50/627], Loss: total=3.296, reg=0.317, containing_obj=0.798, no_obj=0.258, cls=0.787
# Epoch [9/60], Iter [100/627], Loss: total=3.108, reg=0.289, containing_obj=0.760, no_obj=0.256, cls=0.776
# Epoch [9/60], Iter [150/627], Loss: total=3.112, reg=0.293, containing_obj=0.751, no_obj=0.252, cls=0.771
# Epoch [9/60], Iter [200/627], Loss: total=3.114, reg=0.293, containing_obj=0.743, no_obj=0.253, cls=0.779
# Epoch [9/60], Iter [250/627], Loss: total=3.150, reg=0.296, containing_obj=0.752, no_obj=0.255, cls=0.793
# Epoch [9/60], Iter [300/627], Loss: total=3.172, reg=0.297, containing_obj=0.755, no_obj=0.254, cls=0.804
# Epoch [9/60], Iter [350/627], Loss: total=3.201, reg=0.301, containing_obj=0.758, no_obj=0.253, cls=0.812
# Epoch [9/60], Iter [400/627], Loss: total=3.210, reg=0.302, containing_obj=0.760, no_obj=0.254, cls=0.813
# Epoch [9/60], Iter [450/627], Loss: total=3.234, reg=0.305, containing_obj=0.763, no_obj=0.253, cls=0.821
# Epoch [9/60], Iter [500/627], Loss: total=3.227, reg=0.303, containing_obj=0.766, no_obj=0.255, cls=0.818
# Epoch [9/60], Iter [550/627], Loss: total=3.230, reg=0.304, containing_obj=0.767, no_obj=0.256, cls=0.814
# Epoch [9/60], Iter [600/627], Loss: total=3.223, reg=0.303, containing_obj=0.764, no_obj=0.258, cls=0.815
# Updating best test loss: 3.29954
#
#
# Starting epoch 10 / 60
# Learning Rate for this epoch: 0.001
# Epoch [10/60], Iter [50/627], Loss: total=2.889, reg=0.265, containing_obj=0.722, no_obj=0.279, cls=0.701
# Epoch [10/60], Iter [100/627], Loss: total=3.059, reg=0.287, containing_obj=0.751, no_obj=0.279, cls=0.735
# Epoch [10/60], Iter [150/627], Loss: total=3.091, reg=0.293, containing_obj=0.755, no_obj=0.274, cls=0.736
# Epoch [10/60], Iter [200/627], Loss: total=3.113, reg=0.297, containing_obj=0.759, no_obj=0.274, cls=0.730
# Epoch [10/60], Iter [250/627], Loss: total=3.081, reg=0.293, containing_obj=0.754, no_obj=0.273, cls=0.726
# Epoch [10/60], Iter [300/627], Loss: total=3.097, reg=0.293, containing_obj=0.760, no_obj=0.271, cls=0.734
# Epoch [10/60], Iter [350/627], Loss: total=3.122, reg=0.295, containing_obj=0.767, no_obj=0.271, cls=0.742
# Epoch [10/60], Iter [400/627], Loss: total=3.117, reg=0.295, containing_obj=0.763, no_obj=0.273, cls=0.742
# Epoch [10/60], Iter [450/627], Loss: total=3.113, reg=0.295, containing_obj=0.762, no_obj=0.275, cls=0.739
# Epoch [10/60], Iter [500/627], Loss: total=3.095, reg=0.292, containing_obj=0.758, no_obj=0.274, cls=0.740
# Epoch [10/60], Iter [550/627], Loss: total=3.085, reg=0.291, containing_obj=0.753, no_obj=0.276, cls=0.737
# Epoch [10/60], Iter [600/627], Loss: total=3.093, reg=0.292, containing_obj=0.755, no_obj=0.275, cls=0.738
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:13<00:00, 37.19it/s]
# ---class aeroplane ap 0.3292243928750829---
# ---class bicycle ap 0.3112002590535315---
# ---class bird ap 0.22070735552879028---
# ---class boat ap 0.08043492382778168---
# ---class bottle ap 0.015240403760419196---
# ---class bus ap 0.3472693861340196---
# ---class car ap 0.49137609588988407---
# ---class cat ap 0.34883291337786815---
# ---class chair ap 0.1284682939299362---
# ---class cow ap 0.08106216154714323---
# ---class diningtable ap 0.02402189022015287---
# ---class dog ap 0.29367560001094817---
# ---class horse ap 0.4137527323501171---
# ---class motorbike ap 0.3687545415604922---
# ---class person ap 0.36041606748899735---
# ---class pottedplant ap 0.03395181329428983---
# ---class sheep ap 0.09038306878442816---
# ---class sofa ap 0.1557804710283443---
# ---class train ap 0.4808640707162771---
# ---class tvmonitor ap 0.2712037859304474---
# ---map 0.24233101136544755---
# 9 [0.3292243928750829, 0.3112002590535315, 0.22070735552879028, 0.08043492382778168, 0.015240403760419196, 0.3472693861340196, 0.49137609588988407, 0.34883291337786815, 0.1284682939299362, 0.08106216154714323, 0.02402189022015287, 0.29367560001094817, 0.4137527323501171, 0.3687545415604922, 0.36041606748899735, 0.03395181329428983, 0.09038306878442816, 0.1557804710283443, 0.4808640707162771, 0.2712037859304474]
# Updating best test loss: 3.22464
#
#
# Starting epoch 11 / 60
# Learning Rate for this epoch: 0.001
# Epoch [11/60], Iter [50/627], Loss: total=2.965, reg=0.281, containing_obj=0.744, no_obj=0.272, cls=0.682
# Epoch [11/60], Iter [100/627], Loss: total=3.077, reg=0.291, containing_obj=0.768, no_obj=0.271, cls=0.720
# Epoch [11/60], Iter [150/627], Loss: total=3.049, reg=0.287, containing_obj=0.762, no_obj=0.280, cls=0.710
# Epoch [11/60], Iter [200/627], Loss: total=2.995, reg=0.284, containing_obj=0.748, no_obj=0.280, cls=0.687
# Epoch [11/60], Iter [250/627], Loss: total=2.983, reg=0.284, containing_obj=0.740, no_obj=0.278, cls=0.685
# Epoch [11/60], Iter [300/627], Loss: total=2.958, reg=0.282, containing_obj=0.733, no_obj=0.279, cls=0.676
# Epoch [11/60], Iter [350/627], Loss: total=2.967, reg=0.283, containing_obj=0.734, no_obj=0.281, cls=0.675
# Epoch [11/60], Iter [400/627], Loss: total=3.018, reg=0.290, containing_obj=0.743, no_obj=0.279, cls=0.683
# Epoch [11/60], Iter [450/627], Loss: total=3.014, reg=0.290, containing_obj=0.742, no_obj=0.279, cls=0.682
# Epoch [11/60], Iter [500/627], Loss: total=3.040, reg=0.291, containing_obj=0.743, no_obj=0.281, cls=0.701
# Epoch [11/60], Iter [550/627], Loss: total=3.029, reg=0.289, containing_obj=0.743, no_obj=0.280, cls=0.699
# Epoch [11/60], Iter [600/627], Loss: total=3.020, reg=0.288, containing_obj=0.741, no_obj=0.279, cls=0.698
# Updating best test loss: 3.16162
#
#
# Starting epoch 12 / 60
# Learning Rate for this epoch: 0.001
# Epoch [12/60], Iter [50/627], Loss: total=2.877, reg=0.274, containing_obj=0.719, no_obj=0.295, cls=0.640
# Epoch [12/60], Iter [100/627], Loss: total=2.987, reg=0.288, containing_obj=0.735, no_obj=0.301, cls=0.662
# Epoch [12/60], Iter [150/627], Loss: total=2.975, reg=0.287, containing_obj=0.734, no_obj=0.301, cls=0.654
# Epoch [12/60], Iter [200/627], Loss: total=3.013, reg=0.292, containing_obj=0.742, no_obj=0.293, cls=0.663
# Epoch [12/60], Iter [250/627], Loss: total=3.002, reg=0.293, containing_obj=0.741, no_obj=0.294, cls=0.650
# Epoch [12/60], Iter [300/627], Loss: total=3.015, reg=0.295, containing_obj=0.744, no_obj=0.296, cls=0.645
# Epoch [12/60], Iter [350/627], Loss: total=3.001, reg=0.293, containing_obj=0.743, no_obj=0.297, cls=0.642
# Epoch [12/60], Iter [400/627], Loss: total=2.977, reg=0.290, containing_obj=0.740, no_obj=0.297, cls=0.637
# Epoch [12/60], Iter [450/627], Loss: total=2.960, reg=0.289, containing_obj=0.737, no_obj=0.297, cls=0.632
# Epoch [12/60], Iter [500/627], Loss: total=2.953, reg=0.286, containing_obj=0.736, no_obj=0.297, cls=0.636
# Epoch [12/60], Iter [550/627], Loss: total=2.949, reg=0.287, containing_obj=0.734, no_obj=0.296, cls=0.634
# Epoch [12/60], Iter [600/627], Loss: total=2.947, reg=0.285, containing_obj=0.733, no_obj=0.296, cls=0.639
# Updating best test loss: 3.09607
#
#
# Starting epoch 13 / 60
# Learning Rate for this epoch: 0.001
# Epoch [13/60], Iter [50/627], Loss: total=2.505, reg=0.239, containing_obj=0.666, no_obj=0.290, cls=0.500
# Epoch [13/60], Iter [100/627], Loss: total=2.647, reg=0.256, containing_obj=0.690, no_obj=0.299, cls=0.528
# Epoch [13/60], Iter [150/627], Loss: total=2.734, reg=0.265, containing_obj=0.715, no_obj=0.297, cls=0.547
# Epoch [13/60], Iter [200/627], Loss: total=2.756, reg=0.266, containing_obj=0.717, no_obj=0.297, cls=0.559
# Epoch [13/60], Iter [250/627], Loss: total=2.749, reg=0.264, containing_obj=0.714, no_obj=0.300, cls=0.566
# Epoch [13/60], Iter [300/627], Loss: total=2.773, reg=0.267, containing_obj=0.714, no_obj=0.297, cls=0.576
# Epoch [13/60], Iter [350/627], Loss: total=2.817, reg=0.270, containing_obj=0.719, no_obj=0.300, cls=0.600
# Epoch [13/60], Iter [400/627], Loss: total=2.810, reg=0.269, containing_obj=0.717, no_obj=0.300, cls=0.601
# Epoch [13/60], Iter [450/627], Loss: total=2.824, reg=0.271, containing_obj=0.720, no_obj=0.299, cls=0.600
# Epoch [13/60], Iter [500/627], Loss: total=2.841, reg=0.273, containing_obj=0.722, no_obj=0.297, cls=0.603
# Epoch [13/60], Iter [550/627], Loss: total=2.856, reg=0.275, containing_obj=0.728, no_obj=0.297, cls=0.603
# Epoch [13/60], Iter [600/627], Loss: total=2.865, reg=0.277, containing_obj=0.730, no_obj=0.296, cls=0.604
# Updating best test loss: 3.06114
#
#
# Starting epoch 14 / 60
# Learning Rate for this epoch: 0.001
# Epoch [14/60], Iter [50/627], Loss: total=2.694, reg=0.249, containing_obj=0.705, no_obj=0.310, cls=0.590
# Epoch [14/60], Iter [100/627], Loss: total=2.734, reg=0.260, containing_obj=0.703, no_obj=0.317, cls=0.570
# Epoch [14/60], Iter [150/627], Loss: total=2.734, reg=0.260, containing_obj=0.705, no_obj=0.317, cls=0.571
# Epoch [14/60], Iter [200/627], Loss: total=2.685, reg=0.256, containing_obj=0.700, no_obj=0.320, cls=0.545
# Epoch [14/60], Iter [250/627], Loss: total=2.744, reg=0.261, containing_obj=0.713, no_obj=0.316, cls=0.571
# Epoch [14/60], Iter [300/627], Loss: total=2.719, reg=0.258, containing_obj=0.704, no_obj=0.321, cls=0.563
# Epoch [14/60], Iter [350/627], Loss: total=2.739, reg=0.262, containing_obj=0.707, no_obj=0.317, cls=0.563
# Epoch [14/60], Iter [400/627], Loss: total=2.763, reg=0.265, containing_obj=0.710, no_obj=0.315, cls=0.571
# Epoch [14/60], Iter [450/627], Loss: total=2.777, reg=0.267, containing_obj=0.710, no_obj=0.315, cls=0.577
# Epoch [14/60], Iter [500/627], Loss: total=2.796, reg=0.269, containing_obj=0.714, no_obj=0.312, cls=0.580
# Epoch [14/60], Iter [550/627], Loss: total=2.782, reg=0.267, containing_obj=0.713, no_obj=0.312, cls=0.576
# Epoch [14/60], Iter [600/627], Loss: total=2.790, reg=0.267, containing_obj=0.719, no_obj=0.311, cls=0.578
#
#
# Starting epoch 15 / 60
# Learning Rate for this epoch: 0.001
# Epoch [15/60], Iter [50/627], Loss: total=2.754, reg=0.267, containing_obj=0.743, no_obj=0.300, cls=0.527
# Epoch [15/60], Iter [100/627], Loss: total=2.717, reg=0.265, containing_obj=0.736, no_obj=0.311, cls=0.503
# Epoch [15/60], Iter [150/627], Loss: total=2.727, reg=0.264, containing_obj=0.732, no_obj=0.309, cls=0.522
# Epoch [15/60], Iter [200/627], Loss: total=2.693, reg=0.258, containing_obj=0.722, no_obj=0.312, cls=0.527
# Epoch [15/60], Iter [250/627], Loss: total=2.727, reg=0.261, containing_obj=0.726, no_obj=0.313, cls=0.541
# Epoch [15/60], Iter [300/627], Loss: total=2.727, reg=0.260, containing_obj=0.725, no_obj=0.317, cls=0.542
# Epoch [15/60], Iter [350/627], Loss: total=2.716, reg=0.258, containing_obj=0.721, no_obj=0.316, cls=0.546
# Epoch [15/60], Iter [400/627], Loss: total=2.718, reg=0.258, containing_obj=0.717, no_obj=0.316, cls=0.555
# Epoch [15/60], Iter [450/627], Loss: total=2.703, reg=0.257, containing_obj=0.710, no_obj=0.317, cls=0.548
# Epoch [15/60], Iter [500/627], Loss: total=2.699, reg=0.257, containing_obj=0.711, no_obj=0.313, cls=0.548
# Epoch [15/60], Iter [550/627], Loss: total=2.728, reg=0.261, containing_obj=0.715, no_obj=0.313, cls=0.553
# Epoch [15/60], Iter [600/627], Loss: total=2.733, reg=0.261, containing_obj=0.715, no_obj=0.314, cls=0.555
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:13<00:00, 37.03it/s]
# ---class aeroplane ap 0.3981963995552187---
# ---class bicycle ap 0.48612262310795373---
# ---class bird ap 0.36257705785014965---
# ---class boat ap 0.1349758600395775---
# ---class bottle ap 0.08553553866494705---
# ---class bus ap 0.4516021395334886---
# ---class car ap 0.4869495916655657---
# ---class cat ap 0.4971295339505112---
# ---class chair ap 0.20026639077160613---
# ---class cow ap 0.2818760269035374---
# ---class diningtable ap 0.30828036015638804---
# ---class dog ap 0.42240515010509105---
# ---class horse ap 0.56711991324837---
# ---class motorbike ap 0.40945319257864493---
# ---class person ap 0.3896267459695316---
# ---class pottedplant ap 0.0633837973992238---
# ---class sheep ap 0.13037520341888123---
# ---class sofa ap 0.2785830645133612---
# ---class train ap 0.5233891892995972---
# ---class tvmonitor ap 0.3379978780453536---
# ---map 0.34079228283884994---
# 14 [0.3981963995552187, 0.48612262310795373, 0.36257705785014965, 0.1349758600395775, 0.08553553866494705, 0.4516021395334886, 0.4869495916655657, 0.4971295339505112, 0.20026639077160613, 0.2818760269035374, 0.30828036015638804, 0.42240515010509105, 0.56711991324837, 0.40945319257864493, 0.3896267459695316, 0.0633837973992238, 0.13037520341888123, 0.2785830645133612, 0.5233891892995972, 0.3379978780453536]
# Updating best test loss: 3.02716
#
#
# Starting epoch 16 / 60
# Learning Rate for this epoch: 0.001
# Epoch [16/60], Iter [50/627], Loss: total=2.567, reg=0.242, containing_obj=0.689, no_obj=0.335, cls=0.499
# Epoch [16/60], Iter [100/627], Loss: total=2.679, reg=0.255, containing_obj=0.713, no_obj=0.322, cls=0.533
# Epoch [16/60], Iter [150/627], Loss: total=2.702, reg=0.257, containing_obj=0.700, no_obj=0.326, cls=0.555
# Epoch [16/60], Iter [200/627], Loss: total=2.664, reg=0.253, containing_obj=0.698, no_obj=0.324, cls=0.538
# Epoch [16/60], Iter [250/627], Loss: total=2.677, reg=0.255, containing_obj=0.715, no_obj=0.321, cls=0.524
# Epoch [16/60], Iter [300/627], Loss: total=2.686, reg=0.258, containing_obj=0.713, no_obj=0.320, cls=0.523
# Epoch [16/60], Iter [350/627], Loss: total=2.685, reg=0.258, containing_obj=0.714, no_obj=0.320, cls=0.521
# Epoch [16/60], Iter [400/627], Loss: total=2.672, reg=0.257, containing_obj=0.709, no_obj=0.320, cls=0.519
# Epoch [16/60], Iter [450/627], Loss: total=2.679, reg=0.257, containing_obj=0.713, no_obj=0.321, cls=0.523
# Epoch [16/60], Iter [500/627], Loss: total=2.688, reg=0.258, containing_obj=0.715, no_obj=0.321, cls=0.521
# Epoch [16/60], Iter [550/627], Loss: total=2.698, reg=0.260, containing_obj=0.716, no_obj=0.324, cls=0.519
# Epoch [16/60], Iter [600/627], Loss: total=2.699, reg=0.260, containing_obj=0.712, no_obj=0.324, cls=0.524
# Updating best test loss: 2.93676
#
#
# Starting epoch 17 / 60
# Learning Rate for this epoch: 0.001
# Epoch [17/60], Iter [50/627], Loss: total=2.489, reg=0.229, containing_obj=0.655, no_obj=0.330, cls=0.522
# Epoch [17/60], Iter [100/627], Loss: total=2.543, reg=0.241, containing_obj=0.686, no_obj=0.329, cls=0.489
# Epoch [17/60], Iter [150/627], Loss: total=2.503, reg=0.236, containing_obj=0.680, no_obj=0.329, cls=0.480
# Epoch [17/60], Iter [200/627], Loss: total=2.565, reg=0.243, containing_obj=0.688, no_obj=0.326, cls=0.499
# Epoch [17/60], Iter [250/627], Loss: total=2.549, reg=0.241, containing_obj=0.688, no_obj=0.326, cls=0.491
# Epoch [17/60], Iter [300/627], Loss: total=2.553, reg=0.242, containing_obj=0.691, no_obj=0.329, cls=0.486
# Epoch [17/60], Iter [350/627], Loss: total=2.555, reg=0.244, containing_obj=0.691, no_obj=0.332, cls=0.480
# Epoch [17/60], Iter [400/627], Loss: total=2.561, reg=0.244, containing_obj=0.691, no_obj=0.334, cls=0.481
# Epoch [17/60], Iter [450/627], Loss: total=2.554, reg=0.244, containing_obj=0.691, no_obj=0.334, cls=0.476
# Epoch [17/60], Iter [500/627], Loss: total=2.539, reg=0.242, containing_obj=0.686, no_obj=0.333, cls=0.474
# Epoch [17/60], Iter [550/627], Loss: total=2.579, reg=0.247, containing_obj=0.693, no_obj=0.333, cls=0.483
# Epoch [17/60], Iter [600/627], Loss: total=2.606, reg=0.250, containing_obj=0.702, no_obj=0.334, cls=0.486
#
#
# Starting epoch 18 / 60
# Learning Rate for this epoch: 0.001
# Epoch [18/60], Iter [50/627], Loss: total=2.315, reg=0.227, containing_obj=0.617, no_obj=0.327, cls=0.399
# Epoch [18/60], Iter [100/627], Loss: total=2.341, reg=0.228, containing_obj=0.645, no_obj=0.333, cls=0.389
# Epoch [18/60], Iter [150/627], Loss: total=2.523, reg=0.244, containing_obj=0.686, no_obj=0.330, cls=0.450
# Epoch [18/60], Iter [200/627], Loss: total=2.547, reg=0.248, containing_obj=0.687, no_obj=0.334, cls=0.451
# Epoch [18/60], Iter [250/627], Loss: total=2.568, reg=0.251, containing_obj=0.687, no_obj=0.336, cls=0.460
# Epoch [18/60], Iter [300/627], Loss: total=2.548, reg=0.248, containing_obj=0.685, no_obj=0.336, cls=0.455
# Epoch [18/60], Iter [350/627], Loss: total=2.586, reg=0.252, containing_obj=0.700, no_obj=0.332, cls=0.461
# Epoch [18/60], Iter [400/627], Loss: total=2.590, reg=0.251, containing_obj=0.705, no_obj=0.334, cls=0.461
# Epoch [18/60], Iter [450/627], Loss: total=2.583, reg=0.250, containing_obj=0.701, no_obj=0.335, cls=0.462
# Epoch [18/60], Iter [500/627], Loss: total=2.605, reg=0.252, containing_obj=0.708, no_obj=0.333, cls=0.469
# Epoch [18/60], Iter [550/627], Loss: total=2.583, reg=0.249, containing_obj=0.703, no_obj=0.334, cls=0.466
# Epoch [18/60], Iter [600/627], Loss: total=2.595, reg=0.250, containing_obj=0.707, no_obj=0.334, cls=0.474
#
#
# Starting epoch 19 / 60
# Learning Rate for this epoch: 0.001
# Epoch [19/60], Iter [50/627], Loss: total=2.418, reg=0.229, containing_obj=0.644, no_obj=0.336, cls=0.461
# Epoch [19/60], Iter [100/627], Loss: total=2.483, reg=0.238, containing_obj=0.663, no_obj=0.338, cls=0.460
# Epoch [19/60], Iter [150/627], Loss: total=2.487, reg=0.238, containing_obj=0.666, no_obj=0.342, cls=0.461
# Epoch [19/60], Iter [200/627], Loss: total=2.484, reg=0.238, containing_obj=0.662, no_obj=0.336, cls=0.462
# Epoch [19/60], Iter [250/627], Loss: total=2.493, reg=0.239, containing_obj=0.674, no_obj=0.337, cls=0.454
# Epoch [19/60], Iter [300/627], Loss: total=2.500, reg=0.241, containing_obj=0.677, no_obj=0.337, cls=0.448
# Epoch [19/60], Iter [350/627], Loss: total=2.468, reg=0.239, containing_obj=0.669, no_obj=0.340, cls=0.435
# Epoch [19/60], Iter [400/627], Loss: total=2.476, reg=0.240, containing_obj=0.673, no_obj=0.340, cls=0.431
# Epoch [19/60], Iter [450/627], Loss: total=2.486, reg=0.241, containing_obj=0.682, no_obj=0.339, cls=0.430
# Epoch [19/60], Iter [500/627], Loss: total=2.471, reg=0.239, containing_obj=0.680, no_obj=0.340, cls=0.428
# Epoch [19/60], Iter [550/627], Loss: total=2.489, reg=0.240, containing_obj=0.684, no_obj=0.339, cls=0.435
# Epoch [19/60], Iter [600/627], Loss: total=2.499, reg=0.241, containing_obj=0.688, no_obj=0.340, cls=0.435
# Updating best test loss: 2.83881
#
#
# Starting epoch 20 / 60
# Learning Rate for this epoch: 0.001
# Epoch [20/60], Iter [50/627], Loss: total=2.316, reg=0.216, containing_obj=0.648, no_obj=0.343, cls=0.416
# Epoch [20/60], Iter [100/627], Loss: total=2.432, reg=0.231, containing_obj=0.663, no_obj=0.340, cls=0.444
# Epoch [20/60], Iter [150/627], Loss: total=2.435, reg=0.231, containing_obj=0.665, no_obj=0.353, cls=0.437
# Epoch [20/60], Iter [200/627], Loss: total=2.535, reg=0.239, containing_obj=0.691, no_obj=0.352, cls=0.472
# Epoch [20/60], Iter [250/627], Loss: total=2.504, reg=0.237, containing_obj=0.685, no_obj=0.347, cls=0.459
# Epoch [20/60], Iter [300/627], Loss: total=2.492, reg=0.239, containing_obj=0.681, no_obj=0.354, cls=0.441
# Epoch [20/60], Iter [350/627], Loss: total=2.485, reg=0.239, containing_obj=0.674, no_obj=0.353, cls=0.438
# Epoch [20/60], Iter [400/627], Loss: total=2.490, reg=0.240, containing_obj=0.679, no_obj=0.351, cls=0.437
# Epoch [20/60], Iter [450/627], Loss: total=2.483, reg=0.240, containing_obj=0.678, no_obj=0.351, cls=0.430
# Epoch [20/60], Iter [500/627], Loss: total=2.475, reg=0.239, containing_obj=0.680, no_obj=0.350, cls=0.425
# Epoch [20/60], Iter [550/627], Loss: total=2.472, reg=0.238, containing_obj=0.680, no_obj=0.350, cls=0.425
# Epoch [20/60], Iter [600/627], Loss: total=2.481, reg=0.239, containing_obj=0.683, no_obj=0.351, cls=0.426
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:13<00:00, 37.09it/s]
# ---class aeroplane ap 0.3718579665141333---
# ---class bicycle ap 0.4785250612307888---
# ---class bird ap 0.33412895837243456---
# ---class boat ap 0.15243135987151807---
# ---class bottle ap 0.10731202459526727---
# ---class bus ap 0.42499990042735775---
# ---class car ap 0.4767315694942772---
# ---class cat ap 0.5776473180637669---
# ---class chair ap 0.25857303157423595---
# ---class cow ap 0.33221974511796115---
# ---class diningtable ap 0.32116026958884514---
# ---class dog ap 0.5169023794488496---
# ---class horse ap 0.5500791565752241---
# ---class motorbike ap 0.41390876112745434---
# ---class person ap 0.413851860113154---
# ---class pottedplant ap 0.08397449742036225---
# ---class sheep ap 0.2754628124008378---
# ---class sofa ap 0.40400632380152446---
# ---class train ap 0.5787142852387153---
# ---class tvmonitor ap 0.4342795510525389---
# ---map 0.3753383416014623---
# 19 [0.3718579665141333, 0.4785250612307888, 0.33412895837243456, 0.15243135987151807, 0.10731202459526727, 0.42499990042735775, 0.4767315694942772, 0.5776473180637669, 0.25857303157423595, 0.33221974511796115, 0.32116026958884514, 0.5169023794488496, 0.5500791565752241, 0.41390876112745434, 0.413851860113154, 0.08397449742036225, 0.2754628124008378, 0.40400632380152446, 0.5787142852387153, 0.4342795510525389]
#
#
# Starting epoch 21 / 60
# Learning Rate for this epoch: 0.001
# Epoch [21/60], Iter [50/627], Loss: total=2.378, reg=0.223, containing_obj=0.690, no_obj=0.339, cls=0.402
# Epoch [21/60], Iter [100/627], Loss: total=2.347, reg=0.222, containing_obj=0.658, no_obj=0.349, cls=0.404
# Epoch [21/60], Iter [150/627], Loss: total=2.395, reg=0.230, containing_obj=0.674, no_obj=0.340, cls=0.402
# Epoch [21/60], Iter [200/627], Loss: total=2.425, reg=0.235, containing_obj=0.681, no_obj=0.340, cls=0.400
# Epoch [21/60], Iter [250/627], Loss: total=2.426, reg=0.236, containing_obj=0.680, no_obj=0.345, cls=0.393
# Epoch [21/60], Iter [300/627], Loss: total=2.430, reg=0.236, containing_obj=0.685, no_obj=0.342, cls=0.395
# Epoch [21/60], Iter [350/627], Loss: total=2.448, reg=0.237, containing_obj=0.687, no_obj=0.342, cls=0.403
# Epoch [21/60], Iter [400/627], Loss: total=2.453, reg=0.237, containing_obj=0.692, no_obj=0.344, cls=0.405
# Epoch [21/60], Iter [450/627], Loss: total=2.431, reg=0.235, containing_obj=0.683, no_obj=0.346, cls=0.398
# Epoch [21/60], Iter [500/627], Loss: total=2.438, reg=0.236, containing_obj=0.685, no_obj=0.346, cls=0.398
# Epoch [21/60], Iter [550/627], Loss: total=2.419, reg=0.234, containing_obj=0.679, no_obj=0.346, cls=0.398
# Epoch [21/60], Iter [600/627], Loss: total=2.420, reg=0.234, containing_obj=0.678, no_obj=0.345, cls=0.399
# Updating best test loss: 2.82602
#
#
# Starting epoch 22 / 60
# Learning Rate for this epoch: 0.001
# Epoch [22/60], Iter [50/627], Loss: total=2.356, reg=0.222, containing_obj=0.688, no_obj=0.359, cls=0.376
# Epoch [22/60], Iter [100/627], Loss: total=2.226, reg=0.213, containing_obj=0.645, no_obj=0.354, cls=0.338
# Epoch [22/60], Iter [150/627], Loss: total=2.273, reg=0.218, containing_obj=0.646, no_obj=0.352, cls=0.359
# Epoch [22/60], Iter [200/627], Loss: total=2.280, reg=0.218, containing_obj=0.649, no_obj=0.351, cls=0.364
# Epoch [22/60], Iter [250/627], Loss: total=2.330, reg=0.224, containing_obj=0.658, no_obj=0.349, cls=0.376
# Epoch [22/60], Iter [300/627], Loss: total=2.352, reg=0.226, containing_obj=0.666, no_obj=0.349, cls=0.382
# Epoch [22/60], Iter [350/627], Loss: total=2.358, reg=0.227, containing_obj=0.671, no_obj=0.351, cls=0.378
# Epoch [22/60], Iter [400/627], Loss: total=2.353, reg=0.226, containing_obj=0.671, no_obj=0.355, cls=0.372
# Epoch [22/60], Iter [450/627], Loss: total=2.368, reg=0.229, containing_obj=0.672, no_obj=0.355, cls=0.376
# Epoch [22/60], Iter [500/627], Loss: total=2.374, reg=0.230, containing_obj=0.672, no_obj=0.355, cls=0.376
# Epoch [22/60], Iter [550/627], Loss: total=2.376, reg=0.230, containing_obj=0.671, no_obj=0.354, cls=0.375
# Epoch [22/60], Iter [600/627], Loss: total=2.377, reg=0.230, containing_obj=0.673, no_obj=0.354, cls=0.375
#
#
# Starting epoch 23 / 60
# Learning Rate for this epoch: 0.001
# Epoch [23/60], Iter [50/627], Loss: total=2.298, reg=0.218, containing_obj=0.680, no_obj=0.358, cls=0.348
# Epoch [23/60], Iter [100/627], Loss: total=2.169, reg=0.202, containing_obj=0.634, no_obj=0.370, cls=0.338
# Epoch [23/60], Iter [150/627], Loss: total=2.246, reg=0.214, containing_obj=0.655, no_obj=0.360, cls=0.341
# Epoch [23/60], Iter [200/627], Loss: total=2.255, reg=0.214, containing_obj=0.652, no_obj=0.361, cls=0.353
# Epoch [23/60], Iter [250/627], Loss: total=2.283, reg=0.217, containing_obj=0.658, no_obj=0.358, cls=0.362
# Epoch [23/60], Iter [300/627], Loss: total=2.325, reg=0.221, containing_obj=0.669, no_obj=0.357, cls=0.373
# Epoch [23/60], Iter [350/627], Loss: total=2.349, reg=0.223, containing_obj=0.672, no_obj=0.359, cls=0.381
# Epoch [23/60], Iter [400/627], Loss: total=2.349, reg=0.223, containing_obj=0.670, no_obj=0.362, cls=0.381
# Epoch [23/60], Iter [450/627], Loss: total=2.346, reg=0.224, containing_obj=0.670, no_obj=0.362, cls=0.378
# Epoch [23/60], Iter [500/627], Loss: total=2.352, reg=0.224, containing_obj=0.673, no_obj=0.361, cls=0.380
# Epoch [23/60], Iter [550/627], Loss: total=2.350, reg=0.223, containing_obj=0.673, no_obj=0.363, cls=0.381
# Epoch [23/60], Iter [600/627], Loss: total=2.366, reg=0.225, containing_obj=0.674, no_obj=0.361, cls=0.384
# Updating best test loss: 2.80065
#
#
# Starting epoch 24 / 60
# Learning Rate for this epoch: 0.001
# Epoch [24/60], Iter [50/627], Loss: total=2.248, reg=0.207, containing_obj=0.661, no_obj=0.360, cls=0.372
# Epoch [24/60], Iter [100/627], Loss: total=2.262, reg=0.219, containing_obj=0.619, no_obj=0.363, cls=0.366
# Epoch [24/60], Iter [150/627], Loss: total=2.322, reg=0.227, containing_obj=0.636, no_obj=0.358, cls=0.374
# Epoch [24/60], Iter [200/627], Loss: total=2.312, reg=0.224, containing_obj=0.645, no_obj=0.363, cls=0.366
# Epoch [24/60], Iter [250/627], Loss: total=2.312, reg=0.224, containing_obj=0.651, no_obj=0.362, cls=0.358
# Epoch [24/60], Iter [300/627], Loss: total=2.336, reg=0.228, containing_obj=0.662, no_obj=0.362, cls=0.352
# Epoch [24/60], Iter [350/627], Loss: total=2.333, reg=0.228, containing_obj=0.655, no_obj=0.361, cls=0.357
# Epoch [24/60], Iter [400/627], Loss: total=2.332, reg=0.228, containing_obj=0.656, no_obj=0.357, cls=0.355
# Epoch [24/60], Iter [450/627], Loss: total=2.336, reg=0.227, containing_obj=0.659, no_obj=0.357, cls=0.362
# Epoch [24/60], Iter [500/627], Loss: total=2.330, reg=0.226, containing_obj=0.658, no_obj=0.360, cls=0.360
# Epoch [24/60], Iter [550/627], Loss: total=2.331, reg=0.226, containing_obj=0.660, no_obj=0.360, cls=0.359
# Epoch [24/60], Iter [600/627], Loss: total=2.317, reg=0.225, containing_obj=0.657, no_obj=0.360, cls=0.355
# Updating best test loss: 2.78360
#
#
# Starting epoch 25 / 60
# Learning Rate for this epoch: 0.001
# Epoch [25/60], Iter [50/627], Loss: total=2.423, reg=0.241, containing_obj=0.710, no_obj=0.362, cls=0.325
# Epoch [25/60], Iter [100/627], Loss: total=2.297, reg=0.225, containing_obj=0.662, no_obj=0.368, cls=0.326
# Epoch [25/60], Iter [150/627], Loss: total=2.289, reg=0.220, containing_obj=0.671, no_obj=0.368, cls=0.332
# Epoch [25/60], Iter [200/627], Loss: total=2.267, reg=0.217, containing_obj=0.661, no_obj=0.375, cls=0.333
# Epoch [25/60], Iter [250/627], Loss: total=2.291, reg=0.220, containing_obj=0.665, no_obj=0.373, cls=0.341
# Epoch [25/60], Iter [300/627], Loss: total=2.292, reg=0.221, containing_obj=0.663, no_obj=0.369, cls=0.339
# Epoch [25/60], Iter [350/627], Loss: total=2.285, reg=0.219, containing_obj=0.660, no_obj=0.373, cls=0.342
# Epoch [25/60], Iter [400/627], Loss: total=2.269, reg=0.218, containing_obj=0.653, no_obj=0.371, cls=0.341
# Epoch [25/60], Iter [450/627], Loss: total=2.293, reg=0.219, containing_obj=0.661, no_obj=0.371, cls=0.349
# Epoch [25/60], Iter [500/627], Loss: total=2.283, reg=0.219, containing_obj=0.660, no_obj=0.371, cls=0.343
# Epoch [25/60], Iter [550/627], Loss: total=2.282, reg=0.219, containing_obj=0.661, no_obj=0.368, cls=0.343
# Epoch [25/60], Iter [600/627], Loss: total=2.278, reg=0.218, containing_obj=0.664, no_obj=0.367, cls=0.341
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:14<00:00, 36.80it/s]
# ---class aeroplane ap 0.47250503336254396---
# ---class bicycle ap 0.5791703605245182---
# ---class bird ap 0.3938878634002333---
# ---class boat ap 0.26321052645447335---
# ---class bottle ap 0.14923110693002456---
# ---class bus ap 0.512229436808445---
# ---class car ap 0.5633969344323879---
# ---class cat ap 0.6020927712495342---
# ---class chair ap 0.25771732050129137---
# ---class cow ap 0.48080555118546703---
# ---class diningtable ap 0.3547203712741745---
# ---class dog ap 0.5062884273496957---
# ---class horse ap 0.6125891554902838---
# ---class motorbike ap 0.49300379617246304---
# ---class person ap 0.5109737092411424---
# ---class pottedplant ap 0.15881364491335195---
# ---class sheep ap 0.256422576026929---
# ---class sofa ap 0.3715633535085844---
# ---class train ap 0.6244771196176986---
# ---class tvmonitor ap 0.45426933539199454---
# ---map 0.4308684196917619---
# 24 [0.47250503336254396, 0.5791703605245182, 0.3938878634002333, 0.26321052645447335, 0.14923110693002456, 0.512229436808445, 0.5633969344323879, 0.6020927712495342, 0.25771732050129137, 0.48080555118546703, 0.3547203712741745, 0.5062884273496957, 0.6125891554902838, 0.49300379617246304, 0.5109737092411424, 0.15881364491335195, 0.256422576026929, 0.3715633535085844, 0.6244771196176986, 0.45426933539199454]
#
#
# Starting epoch 26 / 60
# Learning Rate for this epoch: 0.001
# Epoch [26/60], Iter [50/627], Loss: total=2.295, reg=0.215, containing_obj=0.702, no_obj=0.349, cls=0.345
# Epoch [26/60], Iter [100/627], Loss: total=2.301, reg=0.219, containing_obj=0.674, no_obj=0.355, cls=0.353
# Epoch [26/60], Iter [150/627], Loss: total=2.247, reg=0.213, containing_obj=0.653, no_obj=0.362, cls=0.349
# Epoch [26/60], Iter [200/627], Loss: total=2.249, reg=0.214, containing_obj=0.653, no_obj=0.369, cls=0.341
# Epoch [26/60], Iter [250/627], Loss: total=2.245, reg=0.215, containing_obj=0.650, no_obj=0.369, cls=0.335
# Epoch [26/60], Iter [300/627], Loss: total=2.219, reg=0.212, containing_obj=0.649, no_obj=0.368, cls=0.324
# Epoch [26/60], Iter [350/627], Loss: total=2.218, reg=0.211, containing_obj=0.651, no_obj=0.366, cls=0.327
# Epoch [26/60], Iter [400/627], Loss: total=2.209, reg=0.211, containing_obj=0.646, no_obj=0.365, cls=0.323
# Epoch [26/60], Iter [450/627], Loss: total=2.226, reg=0.214, containing_obj=0.651, no_obj=0.363, cls=0.325
# Epoch [26/60], Iter [500/627], Loss: total=2.235, reg=0.215, containing_obj=0.651, no_obj=0.359, cls=0.329
# Epoch [26/60], Iter [550/627], Loss: total=2.224, reg=0.214, containing_obj=0.647, no_obj=0.360, cls=0.330
# Epoch [26/60], Iter [600/627], Loss: total=2.223, reg=0.213, containing_obj=0.648, no_obj=0.361, cls=0.331
#
#
# Starting epoch 27 / 60
# Learning Rate for this epoch: 0.001
# Epoch [27/60], Iter [50/627], Loss: total=2.232, reg=0.217, containing_obj=0.668, no_obj=0.366, cls=0.297
# Epoch [27/60], Iter [100/627], Loss: total=2.259, reg=0.218, containing_obj=0.663, no_obj=0.376, cls=0.315
# Epoch [27/60], Iter [150/627], Loss: total=2.241, reg=0.218, containing_obj=0.644, no_obj=0.378, cls=0.318
# Epoch [27/60], Iter [200/627], Loss: total=2.203, reg=0.211, containing_obj=0.647, no_obj=0.375, cls=0.312
# Epoch [27/60], Iter [250/627], Loss: total=2.219, reg=0.212, containing_obj=0.653, no_obj=0.369, cls=0.319
# Epoch [27/60], Iter [300/627], Loss: total=2.218, reg=0.213, containing_obj=0.651, no_obj=0.369, cls=0.320
# Epoch [27/60], Iter [350/627], Loss: total=2.228, reg=0.213, containing_obj=0.652, no_obj=0.368, cls=0.329
# Epoch [27/60], Iter [400/627], Loss: total=2.226, reg=0.211, containing_obj=0.655, no_obj=0.369, cls=0.329
# Epoch [27/60], Iter [450/627], Loss: total=2.223, reg=0.211, containing_obj=0.653, no_obj=0.370, cls=0.328
# Epoch [27/60], Iter [500/627], Loss: total=2.223, reg=0.211, containing_obj=0.654, no_obj=0.370, cls=0.327
# Epoch [27/60], Iter [550/627], Loss: total=2.216, reg=0.211, containing_obj=0.650, no_obj=0.370, cls=0.325
# Epoch [27/60], Iter [600/627], Loss: total=2.226, reg=0.212, containing_obj=0.653, no_obj=0.368, cls=0.327
# Updating best test loss: 2.75686
#
#
# Starting epoch 28 / 60
# Learning Rate for this epoch: 0.001
# Epoch [28/60], Iter [50/627], Loss: total=2.023, reg=0.193, containing_obj=0.619, no_obj=0.407, cls=0.238
# Epoch [28/60], Iter [100/627], Loss: total=2.012, reg=0.193, containing_obj=0.617, no_obj=0.391, cls=0.236
# Epoch [28/60], Iter [150/627], Loss: total=2.047, reg=0.195, containing_obj=0.625, no_obj=0.382, cls=0.255
# Epoch [28/60], Iter [200/627], Loss: total=2.069, reg=0.199, containing_obj=0.622, no_obj=0.376, cls=0.265
# Epoch [28/60], Iter [250/627], Loss: total=2.141, reg=0.206, containing_obj=0.646, no_obj=0.378, cls=0.275
# Epoch [28/60], Iter [300/627], Loss: total=2.167, reg=0.208, containing_obj=0.651, no_obj=0.376, cls=0.288
# Epoch [28/60], Iter [350/627], Loss: total=2.171, reg=0.210, containing_obj=0.650, no_obj=0.381, cls=0.283
# Epoch [28/60], Iter [400/627], Loss: total=2.187, reg=0.211, containing_obj=0.651, no_obj=0.377, cls=0.290
# Epoch [28/60], Iter [450/627], Loss: total=2.176, reg=0.210, containing_obj=0.650, no_obj=0.376, cls=0.287
# Epoch [28/60], Iter [500/627], Loss: total=2.170, reg=0.210, containing_obj=0.648, no_obj=0.375, cls=0.285
# Epoch [28/60], Iter [550/627], Loss: total=2.173, reg=0.210, containing_obj=0.647, no_obj=0.374, cls=0.289
# Epoch [28/60], Iter [600/627], Loss: total=2.188, reg=0.212, containing_obj=0.649, no_obj=0.372, cls=0.294
#
#
# Starting epoch 29 / 60
# Learning Rate for this epoch: 0.001
# Epoch [29/60], Iter [50/627], Loss: total=2.097, reg=0.200, containing_obj=0.628, no_obj=0.343, cls=0.297
# Epoch [29/60], Iter [100/627], Loss: total=2.142, reg=0.203, containing_obj=0.640, no_obj=0.358, cls=0.310
# Epoch [29/60], Iter [150/627], Loss: total=2.134, reg=0.204, containing_obj=0.633, no_obj=0.356, cls=0.305
# Epoch [29/60], Iter [200/627], Loss: total=2.144, reg=0.203, containing_obj=0.637, no_obj=0.360, cls=0.313
# Epoch [29/60], Iter [250/627], Loss: total=2.127, reg=0.200, containing_obj=0.630, no_obj=0.359, cls=0.318
# Epoch [29/60], Iter [300/627], Loss: total=2.134, reg=0.200, containing_obj=0.630, no_obj=0.356, cls=0.324
# Epoch [29/60], Iter [350/627], Loss: total=2.150, reg=0.204, containing_obj=0.632, no_obj=0.359, cls=0.320
# Epoch [29/60], Iter [400/627], Loss: total=2.152, reg=0.204, containing_obj=0.630, no_obj=0.363, cls=0.318
# Epoch [29/60], Iter [450/627], Loss: total=2.156, reg=0.205, containing_obj=0.627, no_obj=0.364, cls=0.319
# Epoch [29/60], Iter [500/627], Loss: total=2.153, reg=0.205, containing_obj=0.629, no_obj=0.363, cls=0.316
# Epoch [29/60], Iter [550/627], Loss: total=2.185, reg=0.209, containing_obj=0.641, no_obj=0.364, cls=0.316
# Epoch [29/60], Iter [600/627], Loss: total=2.192, reg=0.209, containing_obj=0.644, no_obj=0.367, cls=0.320
# Updating best test loss: 2.71917
#
#
# Starting epoch 30 / 60
# Learning Rate for this epoch: 0.001
# Epoch [30/60], Iter [50/627], Loss: total=2.053, reg=0.195, containing_obj=0.642, no_obj=0.395, cls=0.237
# Epoch [30/60], Iter [100/627], Loss: total=2.090, reg=0.204, containing_obj=0.634, no_obj=0.380, cls=0.244
# Epoch [30/60], Iter [150/627], Loss: total=2.110, reg=0.203, containing_obj=0.635, no_obj=0.378, cls=0.273
# Epoch [30/60], Iter [200/627], Loss: total=2.112, reg=0.199, containing_obj=0.642, no_obj=0.379, cls=0.283
# Epoch [30/60], Iter [250/627], Loss: total=2.116, reg=0.200, containing_obj=0.646, no_obj=0.377, cls=0.284
# Epoch [30/60], Iter [300/627], Loss: total=2.141, reg=0.202, containing_obj=0.645, no_obj=0.379, cls=0.299
# Epoch [30/60], Iter [350/627], Loss: total=2.148, reg=0.203, containing_obj=0.644, no_obj=0.380, cls=0.300
# Epoch [30/60], Iter [400/627], Loss: total=2.146, reg=0.203, containing_obj=0.643, no_obj=0.377, cls=0.299
# Epoch [30/60], Iter [450/627], Loss: total=2.149, reg=0.203, containing_obj=0.642, no_obj=0.379, cls=0.302
# Epoch [30/60], Iter [500/627], Loss: total=2.149, reg=0.203, containing_obj=0.646, no_obj=0.379, cls=0.299
# Epoch [30/60], Iter [550/627], Loss: total=2.144, reg=0.203, containing_obj=0.642, no_obj=0.377, cls=0.297
# Epoch [30/60], Iter [600/627], Loss: total=2.139, reg=0.202, containing_obj=0.640, no_obj=0.380, cls=0.300
# ---Evaluate model on test samples---
# ...
# Epoch [51/60], Iter [200/627], Loss: total=1.558, reg=0.142, containing_obj=0.516, no_obj=0.416, cls=0.122
# Epoch [51/60], Iter [250/627], Loss: total=1.564, reg=0.143, containing_obj=0.516, no_obj=0.412, cls=0.126
# Epoch [51/60], Iter [300/627], Loss: total=1.557, reg=0.142, containing_obj=0.509, no_obj=0.415, cls=0.131
# Epoch [51/60], Iter [350/627], Loss: total=1.551, reg=0.140, containing_obj=0.512, no_obj=0.414, cls=0.131
# Epoch [51/60], Iter [400/627], Loss: total=1.572, reg=0.143, containing_obj=0.520, no_obj=0.409, cls=0.133
# Epoch [51/60], Iter [450/627], Loss: total=1.556, reg=0.141, containing_obj=0.514, no_obj=0.407, cls=0.132
# Epoch [51/60], Iter [500/627], Loss: total=1.556, reg=0.141, containing_obj=0.515, no_obj=0.403, cls=0.133
# Epoch [51/60], Iter [550/627], Loss: total=1.547, reg=0.140, containing_obj=0.509, no_obj=0.403, cls=0.136
# Epoch [51/60], Iter [600/627], Loss: total=1.540, reg=0.139, containing_obj=0.508, no_obj=0.404, cls=0.134
# Updating best test loss: 2.57297
#
#
# Starting epoch 52 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [52/60], Iter [50/627], Loss: total=1.495, reg=0.136, containing_obj=0.493, no_obj=0.401, cls=0.120
# Epoch [52/60], Iter [100/627], Loss: total=1.504, reg=0.136, containing_obj=0.496, no_obj=0.399, cls=0.128
# Epoch [52/60], Iter [150/627], Loss: total=1.496, reg=0.136, containing_obj=0.492, no_obj=0.397, cls=0.124
# Epoch [52/60], Iter [200/627], Loss: total=1.522, reg=0.139, containing_obj=0.500, no_obj=0.405, cls=0.125
# Epoch [52/60], Iter [250/627], Loss: total=1.537, reg=0.140, containing_obj=0.506, no_obj=0.402, cls=0.128
# Epoch [52/60], Iter [300/627], Loss: total=1.512, reg=0.138, containing_obj=0.495, no_obj=0.402, cls=0.123
# Epoch [52/60], Iter [350/627], Loss: total=1.499, reg=0.137, containing_obj=0.493, no_obj=0.398, cls=0.121
# Epoch [52/60], Iter [400/627], Loss: total=1.493, reg=0.136, containing_obj=0.493, no_obj=0.397, cls=0.120
# Epoch [52/60], Iter [450/627], Loss: total=1.486, reg=0.135, containing_obj=0.492, no_obj=0.396, cls=0.119
# Epoch [52/60], Iter [500/627], Loss: total=1.491, reg=0.136, containing_obj=0.495, no_obj=0.395, cls=0.117
# Epoch [52/60], Iter [550/627], Loss: total=1.486, reg=0.136, containing_obj=0.491, no_obj=0.396, cls=0.115
# Epoch [52/60], Iter [600/627], Loss: total=1.494, reg=0.137, containing_obj=0.491, no_obj=0.399, cls=0.117
# Updating best test loss: 2.54830
#
#
# Starting epoch 53 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [53/60], Iter [50/627], Loss: total=1.431, reg=0.134, containing_obj=0.437, no_obj=0.383, cls=0.131
# Epoch [53/60], Iter [100/627], Loss: total=1.335, reg=0.122, containing_obj=0.426, no_obj=0.362, cls=0.119
# Epoch [53/60], Iter [150/627], Loss: total=1.399, reg=0.128, containing_obj=0.458, no_obj=0.372, cls=0.113
# Epoch [53/60], Iter [200/627], Loss: total=1.445, reg=0.133, containing_obj=0.477, no_obj=0.378, cls=0.113
# Epoch [53/60], Iter [250/627], Loss: total=1.478, reg=0.137, containing_obj=0.487, no_obj=0.382, cls=0.114
# Epoch [53/60], Iter [300/627], Loss: total=1.472, reg=0.136, containing_obj=0.483, no_obj=0.387, cls=0.114
# Epoch [53/60], Iter [350/627], Loss: total=1.467, reg=0.135, containing_obj=0.483, no_obj=0.388, cls=0.112
# Epoch [53/60], Iter [400/627], Loss: total=1.461, reg=0.134, containing_obj=0.483, no_obj=0.389, cls=0.114
# Epoch [53/60], Iter [450/627], Loss: total=1.463, reg=0.134, containing_obj=0.484, no_obj=0.388, cls=0.114
# Epoch [53/60], Iter [500/627], Loss: total=1.474, reg=0.136, containing_obj=0.484, no_obj=0.390, cls=0.116
# Epoch [53/60], Iter [550/627], Loss: total=1.467, reg=0.135, containing_obj=0.482, no_obj=0.390, cls=0.115
# Epoch [53/60], Iter [600/627], Loss: total=1.457, reg=0.133, containing_obj=0.481, no_obj=0.388, cls=0.115
#
#
# Starting epoch 54 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [54/60], Iter [50/627], Loss: total=1.305, reg=0.117, containing_obj=0.422, no_obj=0.383, cls=0.108
# Epoch [54/60], Iter [100/627], Loss: total=1.341, reg=0.120, containing_obj=0.440, no_obj=0.381, cls=0.111
# Epoch [54/60], Iter [150/627], Loss: total=1.370, reg=0.125, containing_obj=0.445, no_obj=0.375, cls=0.114
# Epoch [54/60], Iter [200/627], Loss: total=1.406, reg=0.129, containing_obj=0.456, no_obj=0.373, cls=0.118
# Epoch [54/60], Iter [250/627], Loss: total=1.435, reg=0.133, containing_obj=0.465, no_obj=0.376, cls=0.119
# Epoch [54/60], Iter [300/627], Loss: total=1.433, reg=0.133, containing_obj=0.463, no_obj=0.377, cls=0.116
# Epoch [54/60], Iter [350/627], Loss: total=1.446, reg=0.134, containing_obj=0.469, no_obj=0.379, cls=0.117
# Epoch [54/60], Iter [400/627], Loss: total=1.450, reg=0.134, containing_obj=0.472, no_obj=0.382, cls=0.115
# Epoch [54/60], Iter [450/627], Loss: total=1.453, reg=0.134, containing_obj=0.476, no_obj=0.386, cls=0.113
# Epoch [54/60], Iter [500/627], Loss: total=1.446, reg=0.134, containing_obj=0.476, no_obj=0.387, cls=0.108
# Epoch [54/60], Iter [550/627], Loss: total=1.454, reg=0.134, containing_obj=0.478, no_obj=0.388, cls=0.112
# Epoch [54/60], Iter [600/627], Loss: total=1.465, reg=0.135, containing_obj=0.483, no_obj=0.385, cls=0.113
# Updating best test loss: 2.54174
#
#
# Starting epoch 55 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [55/60], Iter [50/627], Loss: total=1.421, reg=0.127, containing_obj=0.460, no_obj=0.402, cls=0.122
# Epoch [55/60], Iter [100/627], Loss: total=1.448, reg=0.128, containing_obj=0.485, no_obj=0.419, cls=0.113
# Epoch [55/60], Iter [150/627], Loss: total=1.449, reg=0.128, containing_obj=0.483, no_obj=0.410, cls=0.119
# Epoch [55/60], Iter [200/627], Loss: total=1.422, reg=0.127, containing_obj=0.467, no_obj=0.400, cls=0.119
# Epoch [55/60], Iter [250/627], Loss: total=1.418, reg=0.128, containing_obj=0.465, no_obj=0.395, cls=0.115
# Epoch [55/60], Iter [300/627], Loss: total=1.408, reg=0.128, containing_obj=0.461, no_obj=0.394, cls=0.112
# Epoch [55/60], Iter [350/627], Loss: total=1.411, reg=0.128, containing_obj=0.460, no_obj=0.395, cls=0.112
# Epoch [55/60], Iter [400/627], Loss: total=1.428, reg=0.130, containing_obj=0.467, no_obj=0.396, cls=0.114
# Epoch [55/60], Iter [450/627], Loss: total=1.433, reg=0.131, containing_obj=0.468, no_obj=0.396, cls=0.114
# Epoch [55/60], Iter [500/627], Loss: total=1.431, reg=0.130, containing_obj=0.469, no_obj=0.397, cls=0.112
# Epoch [55/60], Iter [550/627], Loss: total=1.437, reg=0.131, containing_obj=0.470, no_obj=0.396, cls=0.113
# Epoch [55/60], Iter [600/627], Loss: total=1.437, reg=0.131, containing_obj=0.473, no_obj=0.398, cls=0.112
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:12<00:00, 37.34it/s]
# ---class aeroplane ap 0.5044160661106649---
# ---class bicycle ap 0.6665940384446272---
# ---class bird ap 0.5164493482983241---
# ---class boat ap 0.35363408019621134---
# ---class bottle ap 0.2565263951817042---
# ---class bus ap 0.6590374318342171---
# ---class car ap 0.7022717110620429---
# ---class cat ap 0.7267931635476365---
# ---class chair ap 0.3218118885817325---
# ---class cow ap 0.5311298866752536---
# ---class diningtable ap 0.4164030949195799---
# ---class dog ap 0.6614489307363131---
# ---class horse ap 0.6911077567934201---
# ---class motorbike ap 0.6078197981274442---
# ---class person ap 0.584341750693039---
# ---class pottedplant ap 0.21838972134432744---
# ---class sheep ap 0.4804586120963242---
# ---class sofa ap 0.470799913950337---
# ---class train ap 0.6978306230478014---
# ---class tvmonitor ap 0.5112243647554009---
# ---map 0.5289244288198202---
# 54 [0.5044160661106649, 0.6665940384446272, 0.5164493482983241, 0.35363408019621134, 0.2565263951817042, 0.6590374318342171, 0.7022717110620429, 0.7267931635476365, 0.3218118885817325, 0.5311298866752536, 0.4164030949195799, 0.6614489307363131, 0.6911077567934201, 0.6078197981274442, 0.584341750693039, 0.21838972134432744, 0.4804586120963242, 0.470799913950337, 0.6978306230478014, 0.5112243647554009]
#
#
# Starting epoch 56 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [56/60], Iter [50/627], Loss: total=1.392, reg=0.127, containing_obj=0.453, no_obj=0.378, cls=0.117
# Epoch [56/60], Iter [100/627], Loss: total=1.349, reg=0.121, containing_obj=0.445, no_obj=0.387, cls=0.103
# Epoch [56/60], Iter [150/627], Loss: total=1.372, reg=0.124, containing_obj=0.463, no_obj=0.370, cls=0.104
# Epoch [56/60], Iter [200/627], Loss: total=1.383, reg=0.125, containing_obj=0.465, no_obj=0.371, cls=0.109
# Epoch [56/60], Iter [250/627], Loss: total=1.402, reg=0.126, containing_obj=0.472, no_obj=0.376, cls=0.112
# Epoch [56/60], Iter [300/627], Loss: total=1.419, reg=0.126, containing_obj=0.485, no_obj=0.378, cls=0.115
# Epoch [56/60], Iter [350/627], Loss: total=1.436, reg=0.129, containing_obj=0.485, no_obj=0.381, cls=0.116
# Epoch [56/60], Iter [400/627], Loss: total=1.440, reg=0.131, containing_obj=0.483, no_obj=0.381, cls=0.113
# Epoch [56/60], Iter [450/627], Loss: total=1.441, reg=0.131, containing_obj=0.482, no_obj=0.381, cls=0.113
# Epoch [56/60], Iter [500/627], Loss: total=1.434, reg=0.131, containing_obj=0.477, no_obj=0.379, cls=0.115
# Epoch [56/60], Iter [550/627], Loss: total=1.432, reg=0.131, containing_obj=0.479, no_obj=0.380, cls=0.111
# Epoch [56/60], Iter [600/627], Loss: total=1.429, reg=0.130, containing_obj=0.478, no_obj=0.381, cls=0.110
#
#
# Starting epoch 57 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [57/60], Iter [50/627], Loss: total=1.374, reg=0.121, containing_obj=0.471, no_obj=0.382, cls=0.109
# Epoch [57/60], Iter [100/627], Loss: total=1.408, reg=0.125, containing_obj=0.488, no_obj=0.388, cls=0.098
# Epoch [57/60], Iter [150/627], Loss: total=1.397, reg=0.123, containing_obj=0.473, no_obj=0.393, cls=0.110
# Epoch [57/60], Iter [200/627], Loss: total=1.372, reg=0.123, containing_obj=0.461, no_obj=0.385, cls=0.106
# Epoch [57/60], Iter [250/627], Loss: total=1.392, reg=0.124, containing_obj=0.470, no_obj=0.392, cls=0.105
# Epoch [57/60], Iter [300/627], Loss: total=1.376, reg=0.123, containing_obj=0.464, no_obj=0.392, cls=0.101
# Epoch [57/60], Iter [350/627], Loss: total=1.387, reg=0.126, containing_obj=0.465, no_obj=0.384, cls=0.102
# Epoch [57/60], Iter [400/627], Loss: total=1.391, reg=0.126, containing_obj=0.464, no_obj=0.388, cls=0.103
# Epoch [57/60], Iter [450/627], Loss: total=1.403, reg=0.128, containing_obj=0.466, no_obj=0.389, cls=0.104
# Epoch [57/60], Iter [500/627], Loss: total=1.406, reg=0.127, containing_obj=0.466, no_obj=0.390, cls=0.107
# Epoch [57/60], Iter [550/627], Loss: total=1.411, reg=0.128, containing_obj=0.467, no_obj=0.390, cls=0.107
# Epoch [57/60], Iter [600/627], Loss: total=1.407, reg=0.128, containing_obj=0.467, no_obj=0.391, cls=0.106
#
#
# Starting epoch 58 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [58/60], Iter [50/627], Loss: total=1.359, reg=0.118, containing_obj=0.457, no_obj=0.387, cls=0.121
# Epoch [58/60], Iter [100/627], Loss: total=1.354, reg=0.122, containing_obj=0.454, no_obj=0.386, cls=0.095
# Epoch [58/60], Iter [150/627], Loss: total=1.383, reg=0.127, containing_obj=0.457, no_obj=0.384, cls=0.101
# Epoch [58/60], Iter [200/627], Loss: total=1.385, reg=0.125, containing_obj=0.457, no_obj=0.391, cls=0.106
# Epoch [58/60], Iter [250/627], Loss: total=1.385, reg=0.126, containing_obj=0.455, no_obj=0.388, cls=0.107
# Epoch [58/60], Iter [300/627], Loss: total=1.398, reg=0.129, containing_obj=0.456, no_obj=0.389, cls=0.105
# Epoch [58/60], Iter [350/627], Loss: total=1.406, reg=0.129, containing_obj=0.458, no_obj=0.388, cls=0.108
# Epoch [58/60], Iter [400/627], Loss: total=1.414, reg=0.130, containing_obj=0.460, no_obj=0.388, cls=0.108
# Epoch [58/60], Iter [450/627], Loss: total=1.424, reg=0.131, containing_obj=0.463, no_obj=0.390, cls=0.109
# Epoch [58/60], Iter [500/627], Loss: total=1.422, reg=0.131, containing_obj=0.466, no_obj=0.390, cls=0.107
# Epoch [58/60], Iter [550/627], Loss: total=1.416, reg=0.130, containing_obj=0.465, no_obj=0.392, cls=0.104
# Epoch [58/60], Iter [600/627], Loss: total=1.407, reg=0.129, containing_obj=0.462, no_obj=0.389, cls=0.104
#
#
# Starting epoch 59 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [59/60], Iter [50/627], Loss: total=1.423, reg=0.131, containing_obj=0.494, no_obj=0.372, cls=0.089
# Epoch [59/60], Iter [100/627], Loss: total=1.415, reg=0.129, containing_obj=0.481, no_obj=0.398, cls=0.092
# Epoch [59/60], Iter [150/627], Loss: total=1.422, reg=0.128, containing_obj=0.484, no_obj=0.392, cls=0.102
# Epoch [59/60], Iter [200/627], Loss: total=1.426, reg=0.127, containing_obj=0.491, no_obj=0.397, cls=0.101
# Epoch [59/60], Iter [250/627], Loss: total=1.431, reg=0.129, containing_obj=0.485, no_obj=0.393, cls=0.104
# Epoch [59/60], Iter [300/627], Loss: total=1.445, reg=0.131, containing_obj=0.487, no_obj=0.389, cls=0.108
# Epoch [59/60], Iter [350/627], Loss: total=1.438, reg=0.131, containing_obj=0.480, no_obj=0.389, cls=0.108
# Epoch [59/60], Iter [400/627], Loss: total=1.429, reg=0.130, containing_obj=0.480, no_obj=0.384, cls=0.109
# Epoch [59/60], Iter [450/627], Loss: total=1.432, reg=0.130, containing_obj=0.479, no_obj=0.387, cls=0.110
# Epoch [59/60], Iter [500/627], Loss: total=1.424, reg=0.129, containing_obj=0.476, no_obj=0.387, cls=0.108
# Epoch [59/60], Iter [550/627], Loss: total=1.417, reg=0.128, containing_obj=0.473, no_obj=0.386, cls=0.109
# Epoch [59/60], Iter [600/627], Loss: total=1.418, reg=0.129, containing_obj=0.472, no_obj=0.387, cls=0.109
#
#
# Starting epoch 60 / 60
# Learning Rate for this epoch: 0.0001
# Epoch [60/60], Iter [50/627], Loss: total=1.330, reg=0.126, containing_obj=0.430, no_obj=0.348, cls=0.094
# Epoch [60/60], Iter [100/627], Loss: total=1.316, reg=0.119, containing_obj=0.441, no_obj=0.352, cls=0.103
# Epoch [60/60], Iter [150/627], Loss: total=1.342, reg=0.122, containing_obj=0.446, no_obj=0.365, cls=0.101
# Epoch [60/60], Iter [200/627], Loss: total=1.345, reg=0.123, containing_obj=0.442, no_obj=0.375, cls=0.101
# Epoch [60/60], Iter [250/627], Loss: total=1.351, reg=0.124, containing_obj=0.448, no_obj=0.374, cls=0.095
# Epoch [60/60], Iter [300/627], Loss: total=1.354, reg=0.124, containing_obj=0.449, no_obj=0.377, cls=0.097
# Epoch [60/60], Iter [350/627], Loss: total=1.358, reg=0.123, containing_obj=0.453, no_obj=0.377, cls=0.100
# Epoch [60/60], Iter [400/627], Loss: total=1.369, reg=0.123, containing_obj=0.459, no_obj=0.379, cls=0.103
# Epoch [60/60], Iter [450/627], Loss: total=1.361, reg=0.122, containing_obj=0.460, no_obj=0.378, cls=0.101
# Epoch [60/60], Iter [500/627], Loss: total=1.373, reg=0.124, containing_obj=0.464, no_obj=0.377, cls=0.102
# Epoch [60/60], Iter [550/627], Loss: total=1.377, reg=0.125, containing_obj=0.463, no_obj=0.378, cls=0.102
# Epoch [60/60], Iter [600/627], Loss: total=1.389, reg=0.125, containing_obj=0.467, no_obj=0.379, cls=0.105
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:13<00:00, 37.14it/s]
# ---class aeroplane ap 0.5197024547572453---
# ---class bicycle ap 0.6720209662139783---
# ---class bird ap 0.47300446301979704---
# ---class boat ap 0.31997097113073164---
# ---class bottle ap 0.2441026789117926---
# ---class bus ap 0.6604683374415341---
# ---class car ap 0.7090130859944482---
# ---class cat ap 0.7174969052137716---
# ---class chair ap 0.31917243898647196---
# ---class cow ap 0.5850837291097615---
# ---class diningtable ap 0.4374293746134305---
# ---class dog ap 0.6517184115131236---
# ---class horse ap 0.7106170094164139---
# ---class motorbike ap 0.6126093220610553---
# ---class person ap 0.5801102616824383---
# ---class pottedplant ap 0.2140506285853746---
# ---class sheep ap 0.5258636429962245---
# ---class sofa ap 0.5004731821309125---
# ---class train ap 0.7089413744308586---
# ---class tvmonitor ap 0.5369036981453373---
# ---map 0.5349376468177351---
# 59 [0.5197024547572453, 0.6720209662139783, 0.47300446301979704, 0.31997097113073164, 0.2441026789117926, 0.6604683374415341, 0.7090130859944482, 0.7174969052137716, 0.31917243898647196, 0.5850837291097615, 0.4374293746134305, 0.6517184115131236, 0.7106170094164139, 0.6126093220610553, 0.5801102616824383, 0.2140506285853746, 0.5258636429962245, 0.5004731821309125, 0.7089413744308586, 0.5369036981453373]

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████| 4950/4950 [02:17<00:00, 36.02it/s]
# ---class aeroplane ap 0.5197024547572453---
# ---class bicycle ap 0.6720209662139783---
# ---class bird ap 0.47300446301979704---
# ---class boat ap 0.31997097113073164---
# ---class bottle ap 0.2441026789117926---
# ---class bus ap 0.6604683374415341---
# ---class car ap 0.7090130859944482---
# ---class cat ap 0.7174969052137716---
# ---class chair ap 0.31917243898647196---
# ---class cow ap 0.5850837291097615---
# ---class diningtable ap 0.4374293746134305---
# ---class dog ap 0.6517184115131236---
# ---class horse ap 0.7106170094164139---
# ---class motorbike ap 0.6126093220610553---
# ---class person ap 0.5801102616824383---
# ---class pottedplant ap 0.2140506285853746---
# ---class sheep ap 0.5258636429962245---
# ---class sofa ap 0.5004731821309125---
# ---class train ap 0.7089413744308586---
# ---class tvmonitor ap 0.5369036981453373---
# ---map 0.5349376468177351---

# %% [markdown]
# ### Cell added to get intermediate mAP values for students

# %%
network_paths = ['detector_epoch_%d.pth' % epoch for epoch in [5, 10, 20, 30, 40]]+['detector.pth']
for load_network_path in network_paths:
    print('Loading saved network from {}'.format(load_network_path))
    net_loaded =  resnet50().to(device)
    net_loaded.load_state_dict(torch.load(load_network_path))
    evaluate(net_loaded, test_dataset_file=annotation_file_test)
# Out:
# Loading saved network from detector_epoch_5.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/tmp/ipykernel_8569/2271641507.py in <module>
#       3     print('Loading saved network from {}'.format(load_network_path))
#       4     net_loaded =  resnet50().to(device)
# ----> 5     net_loaded.load_state_dict(torch.load(load_network_path))
#       6     evaluate(net_loaded, test_dataset_file=annotation_file_test)
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     769         pickle_load_args['encoding'] = 'utf-8'
#     770
# --> 771     with _open_file_like(f, 'rb') as opened_file:
#     772         if _is_zipfile(opened_file):
#     773             # The zipfile reader is going to advance the current file position.
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     268 def _open_file_like(name_or_buffer, mode):
#     269     if _is_path(name_or_buffer):
# --> 270         return _open_file(name_or_buffer, mode)
#     271     else:
#     272         if 'w' in mode:
#
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py in __init__(self, name, mode)
#     249 class _open_file(_opener):
#     250     def __init__(self, name, mode):
# --> 251         super(_open_file, self).__init__(open(name, mode))
#     252
#     253     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'detector_epoch_5.pth'

# %%
output_submission_csv('my_new_solution.csv', test_aps)
